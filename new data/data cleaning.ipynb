# %%
import pandas as pd

gpay = pd.read_csv(r"C:\Users\Hasan\Projects\razorpay buildathon\new data testing\gpay_history_v2.csv")
bank = pd.read_csv(r"C:\Users\Hasan\Projects\razorpay buildathon\new data testing\bank_statement_v2.csv")

gpay_cols = list(gpay.columns)
bank_cols = list(bank.columns)

print(f"gpay features: {gpay_cols}")
print(f"bank features: {bank_cols}")

normalized_features = set([*gpay_cols , *bank_cols])
normalized_features.remove("Withdrawal")
normalized_features.remove("Deposit")
normalized_features.remove('Payment Method')

print(f"normalized features: {normalized_features}")
# Out:
# gpay features: ['Date', 'Time', 'Description', 'Transaction ID', 'Amount', 'Merchant', 'Notes', 'Payment Method']
# bank features: ['Date', 'Description', 'Withdrawal', 'Deposit', 'Category', 'Currency']
# normalized features: {'Category', 'Currency', 'Date', 'Description', 'Transaction ID', 'Time', 'Notes', 'Amount', 'Merchant'}
